# %%
# Dataset: mtcars.csv
# Location: https://mitu.co.in/dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/mtcars.csv')

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
# separate the input and output data
x = df[['disp','hp','wt']]
y = df['mpg']

# %%
x
# Out:
#      disp   hp     wt
# 0   160.0  110  2.620
# 1   160.0  110  2.875
# 2   108.0   93  2.320
# 3   258.0  110  3.215
# 4   360.0  175  3.440
# 5   225.0  105  3.460
# 6   360.0  245  3.570
# 7   146.7   62  3.190
# 8   140.8   95  3.150
# 9   167.6  123  3.440
# 10  167.6  123  3.440
# 11  275.8  180  4.070
# 12  275.8  180  3.730
# 13  275.8  180  3.780
# 14  472.0  205  5.250
# 15  460.0  215  5.424
# 16  440.0  230  5.345
# 17   78.7   66  2.200
# 18   75.7   52  1.615
# 19   71.1   65  1.835
# 20  120.1   97  2.465
# 21  318.0  150  3.520
# 22  304.0  150  3.435
# 23  350.0  245  3.840
# 24  400.0  175  3.845
# 25   79.0   66  1.935
# 26  120.3   91  2.140
# 27   95.1  113  1.513
# 28  351.0  264  3.170
# 29  145.0  175  2.770
# 30  301.0  335  3.570
# 31  121.0  109  2.780

# %%
x.describe()
# Out:
#              disp          hp         wt
# count   32.000000   32.000000  32.000000
# mean   230.721875  146.687500   3.217250
# std    123.938694   68.562868   0.978457
# min     71.100000   52.000000   1.513000
# 25%    120.825000   96.500000   2.581250
# 50%    196.300000  123.000000   3.325000
# 75%    326.000000  180.000000   3.610000
# max    472.000000  335.000000   5.424000

# %%
# scale the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)

# %%
x_scaled
# Out:
#         disp        hp        wt
# 0   0.221751  0.204947  0.283048
# 1   0.221751  0.204947  0.348249
# 2   0.092043  0.144876  0.206341
# 3   0.466201  0.204947  0.435183
# 4   0.720629  0.434629  0.492713
# 5   0.383886  0.187279  0.497827
# 6   0.720629  0.681979  0.525952
# 7   0.188576  0.035336  0.428791
# 8   0.173859  0.151943  0.418563
# 9   0.240708  0.250883  0.492713
# 10  0.240708  0.250883  0.492713
# 11  0.510601  0.452297  0.653797
# 12  0.510601  0.452297  0.566863
# 13  0.510601  0.452297  0.579647
# 14  1.000000  0.540636  0.955510
# 15  0.970067  0.575972  1.000000
# 16  0.920180  0.628975  0.979801
# 17  0.018957  0.049470  0.175658
# 18  0.011474  0.000000  0.026080
# 19  0.000000  0.045936  0.082332
# 20  0.122225  0.159011  0.243416
# 21  0.615864  0.346290  0.513168
# 22  0.580943  0.346290  0.491434
# 23  0.695685  0.681979  0.594988
# 24  0.820404  0.434629  0.596267
# 25  0.019706  0.049470  0.107901
# 26  0.122724  0.137809  0.160317
# 27  0.059865  0.215548  0.000000
# 28  0.698179  0.749117  0.423677
# 29  0.184335  0.434629  0.321401
# 30  0.573460  1.000000  0.525952
# 31  0.124470  0.201413  0.323958

# %%
x_scaled.describe()
# Out:
#             disp         hp         wt
# count  32.000000  32.000000  32.000000
# mean    0.398159   0.334585   0.435758
# std     0.309151   0.242272   0.250181
# min     0.000000   0.000000   0.000000
# 25%     0.124033   0.157244   0.273140
# 50%     0.312297   0.250883   0.463309
# 75%     0.635819   0.452297   0.536180
# max     1.000000   1.000000   1.000000

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
# cross-validation
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y, random_state=0, test_size=0.25)

# %%
x_train.shape
# Out:
# (24, 3)

# %%
x_test.shape
# Out:
# (8, 3)

# %%
# build the model
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2.6325711781917764

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.1659328460217132

# %%
regressor.score(x_test, y_test)
# Out:
# 0.4853132055038557

# %%
regressor.score(x_train, y_train)
# Out:
# 0.8560828298731675

# %%
regressor.coef_
# Out:
# array([  1.39085753,  -8.99273474, -19.60037325])

# %%
regressor.intercept_
# Out:
# 31.112726151643507

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.title('disp vs. mpg')
plt.scatter(x['disp'], y)
plt.subplot(2,2,2)
plt.title('hp vs. mpg')
plt.scatter(x['hp'], y)
plt.subplot(2,2,3)
plt.title('wt vs. mpg')
plt.scatter(x['wt'], y)

# %%
disp = 221
hp = 102
wt = 2.91

# %%
new = scaler.transform([[disp,hp,wt]])
regressor.predict(new)
# Out:
# /home/mitu/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /home/mitu/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.04275028])

# %%
df = pd.read_csv('datasets/customers.csv')

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
x = df[['Length of Membership']]
y = df['Yearly Amount Spent']

# %%
plt.scatter(x, y)

# %%
# cross-validation
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, random_state=0, test_size=0.25)

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 41.48723178728957

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.08764177312170485

# %%
regressor.score(x_train, y_train)
# Out:
# 0.6784398347492935

# %%
sns.regplot(x='Length of Membership',
            y='Yearly Amount Spent', data=df)
# Out:
# <AxesSubplot:xlabel='Length of Membership', ylabel='Yearly Amount Spent'>
